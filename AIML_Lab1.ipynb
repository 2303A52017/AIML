# %% [markdown]
# Lab01- Implement basic data structures of Numpy, Pandas, Matplotlib and Access Data from sources

# %% [markdown]
# Part 01: Lab Task is implement the following data structures using Numpy and Pandas.**

# %%
import numpy as np
lst1=[1,2,3]
array1 = np.array(lst1)
array1
# Out:
# array([1, 2, 3])

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
type(lst1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
print("array2 multiplied by array1: ",array1*array2)
print("array2 divided by array1: ",array2/array1)
print("array2 raised to the power of array1: ",array2**array1)
# Out:
# array2 multiplied by array1:  [3 4 3]
# array2 divided by array1:  [3.         1.         0.33333333]
# array2 raised to the power of array1:  [3 4 1]

# %%
# sine function
print("Sine: ",np.sin(array1))
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
# Exponential
print("Exponential: ",np.exp(array1))
# Out:
# Sine:  [0.84147098 0.90929743 0.14112001]
# Natural logarithm:  [0.         0.69314718 1.09861229]
# Base-10 logarithm:  [0.         0.30103    0.47712125]
# Base-2 logarithm:  [0.        1.        1.5849625]
# Exponential:  [ 2.71828183  7.3890561  20.08553692]

# %%
print("Adding two numpy arrays {array1} and {array2} together:", array1+array2)
# Out:
# Adding two numpy arrays {array1} and {array2} together: [4 4 4]

# %%
print(f"Adding two numpy arrays {array1} and {array2} together: {array1+array2}")
# Out:
# Adding two numpy arrays [1 2 3] and [3 2 1] together: [4 4 4]

# %% [markdown]
# Part-02: Lab Task is to visualize the datasets or data using Matplotlib builtin function Graphs
# Generate Scatterplot

# %% [markdown]
# Let's suppose we collected age (in years), height (in cm), and weight (in kilograms) information from few patients visitng a clinic.

# %%
people = ['honey','Nani','siddu','rithu','laddu']
age = [21,12,32,45,37]
weight = [55,35,77,68,70]
height = [170,173,168,155,158]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %% [markdown]
# Generate Bar Plot

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,
          fontstyle='italic')
# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,
        color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# Generate Histogram

# %%
import numpy as np
plt.figure(figsize=(7,5))

# Main plot function 'hist'
plt.hist(weight,color='black',edgecolor='k', alpha=0.75,bins=5)

plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# Part-03: Access Data from various sources and formats

# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_table("/content/part-3")

# %%
data1
# Out:
# Empty DataFrame
# Columns: [Part-03: Access Data from various sources and formats]
# Index: []

# %%
data2 = pd.read_csv("/content/business-financial-data-march-2024.zip")

# %%
data2
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 7630     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 7631     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
# 7632     BDCQ.SF8RSCA  2023.09     673.068        NaN      F  Dollars
# 7633     BDCQ.SF8RSCA  2023.12     511.098        NaN      F  Dollars
# 7634     BDCQ.SF8RSCA  2024.03     631.229        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
data3 = pd.read_excel("/content/HistoricalPrices (2).xls")

# %%
data3
# Out:
#                   Date      Open      High       Low     Close
# 0  2024-07-08 00:00:00  39230.09  39477.96  38731.51  38763.45
# 1  2024-06-08 00:00:00  38736.22  39449.53  38638.30  38997.66
# 2  2024-05-08 00:00:00  39056.19  39056.19  38499.27  38703.27
# 3  2024-02-08 00:00:00  40075.33  40075.33  39358.68  39737.26
# 4  2024-01-08 00:00:00  40916.96  41096.66  40098.57  40347.97
# 5             07/31/24  40768.88  41198.63  40655.89  40842.79
# 6             07/30/24  40622.13  40866.25  40529.10  40743.33
# 7             07/29/24  40665.71  40682.49  40388.83  40539.93
